# %%
import pandas as pd
import numpy as np

# %%
location= "../../datasets/DC_Properties.csv"
#location = r"C:\Users\TPCF235009ur\Documents\Data Analytic Bootcamp\datasets\DC_Properties.csv"
df=pd.read_csv(location, low_memory=False)
df.tail()


#df=pd.read_csv("datasets/DC_Properties.csv")
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM        HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 158952      158952       1          0  Forced Air  Y        NaN      3      1
# 158953      158953       1          0  Forced Air  Y        NaN      4      2
# 158954      158954       2          0  Forced Air  Y        NaN      4      2
# 158955      158955       1          0   Warm Cool  Y        NaN      2      0
# 158956      158956       1          0   Warm Cool  Y        NaN      2      0
#
#            AYB  YR_RMDL   ...     LONGITUDE       ASSESSMENT_NBHD  \
# 158952  1938.0   2006.0   ...     -77.01942            Old City 2
# 158953  1938.0   2006.0   ...     -77.01942            Old City 2
# 158954  1920.0   2007.0   ...     -77.01942            Old City 2
# 158955  1965.0      NaN   ...     -77.01823  Southwest Waterfront
# 158956  1965.0      NaN   ...     -77.01823  Southwest Waterfront
#
#        ASSESSMENT_SUBNBHD  CENSUS_TRACT CENSUS_BLOCK    WARD  SQUARE  \
# ...

# %%
df.count()
# Out:
# Unnamed: 0            158957
# BATHRM                158957
# HF_BATHRM             158957
# HEAT                  158957
# AC                    158957
# NUM_UNITS             106696
# ROOMS                 158957
# BEDRM                 158957
# AYB                   158686
# YR_RMDL                80928
# EYB                   158957
# STORIES               106652
# SALEDATE              132187
# PRICE                  98216
# QUALIFIED             158957
# SALE_NUM              158957
# GBA                   106696
# BLDG_NUM              158957
# STYLE                 106696
# STRUCT                106696
# GRADE                 106696
# CNDTN                 106696
# EXTWALL               106696
# ROOF                  106696
# INTWALL               106696
# KITCHENS              106695
# FIREPLACES            158957
# USECODE               158957
# LANDAREA              158957
# GIS_LAST_MOD_DTTM     158957
# SOURCE                158957
# CMPLX_NUM              52261
# ...

# %%
df_neigh.drop_duplicates()
#df.drop_duplicates(['Names'], keep='last')
df_neigh
# Out:
#              ASSESSMENT_NBHD ASSESSMENT_SUBNBHD
# 0                 Old City 2   040 D Old City 2
# 1                 Old City 2   040 D Old City 2
# 2                 Old City 2   040 D Old City 2
# 3                 Old City 2   040 D Old City 2
# 4                 Old City 2   040 D Old City 2
# 5                 Old City 2   040 D Old City 2
# 6                 Old City 2   040 D Old City 2
# 7                 Old City 2   040 D Old City 2
# 8                 Old City 2   040 D Old City 2
# 9                 Old City 2   040 D Old City 2
# 10                Old City 2   040 D Old City 2
# 11                Old City 2   040 D Old City 2
# 12                Old City 2   040 D Old City 2
# 13                Old City 2   040 D Old City 2
# 14                Old City 2   040 D Old City 2
# 15                Old City 2   040 D Old City 2
# 16                Old City 2   040 D Old City 2
# 17                Old City 2   040 D Old City 2
# 18                Old City 2   040 D Old City 2
# ...

# %%
df.shape
# Out:
# (158957, 49)

# %%
df.describe()
# Out:
#           Unnamed: 0         BATHRM      HF_BATHRM      NUM_UNITS  \
# count  158957.000000  158957.000000  158957.000000  106696.000000
# mean    79478.000000       1.810678       0.458237       1.198039
# std     45887.077707       0.976396       0.587571       0.596924
# min         0.000000       0.000000       0.000000       0.000000
# 25%     39739.000000       1.000000       0.000000       1.000000
# 50%     79478.000000       2.000000       0.000000       1.000000
# 75%    119217.000000       2.000000       1.000000       1.000000
# max    158956.000000      14.000000      11.000000       6.000000
#
#                ROOMS          BEDRM            AYB       YR_RMDL  \
# count  158957.000000  158957.000000  158686.000000  80928.000000
# mean        6.187736       2.732506    1941.987579   1998.243537
# std         2.618165       1.358864      33.640234     16.575786
# min         0.000000       0.000000    1754.000000     20.000000
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'BATHRM', 'HF_BATHRM', 'HEAT', 'AC', 'NUM_UNITS', 'ROOMS',
#        'BEDRM', 'AYB', 'YR_RMDL', 'EYB', 'STORIES', 'SALEDATE', 'PRICE',
#        'QUALIFIED', 'SALE_NUM', 'GBA', 'BLDG_NUM', 'STYLE', 'STRUCT', 'GRADE',
#        'CNDTN', 'EXTWALL', 'ROOF', 'INTWALL', 'KITCHENS', 'FIREPLACES',
#        'USECODE', 'LANDAREA', 'GIS_LAST_MOD_DTTM', 'SOURCE', 'CMPLX_NUM',
#        'LIVING_GBA', 'FULLADDRESS', 'CITY', 'STATE', 'ZIPCODE', 'NATIONALGRID',
#        'LATITUDE', 'LONGITUDE', 'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD',
#        'CENSUS_TRACT', 'CENSUS_BLOCK', 'WARD', 'SQUARE', 'X', 'Y', 'QUADRANT'],
#       dtype='object')

# %%
df_no_missing = df.dropna().count()
df_no_missing
#it appears they all have an entry of sorts
# Out:
# Unnamed: 0            0
# BATHRM                0
# HF_BATHRM             0
# HEAT                  0
# AC                    0
# NUM_UNITS             0
# ROOMS                 0
# BEDRM                 0
# AYB                   0
# YR_RMDL               0
# EYB                   0
# STORIES               0
# SALEDATE              0
# PRICE                 0
# QUALIFIED             0
# SALE_NUM              0
# GBA                   0
# BLDG_NUM              0
# STYLE                 0
# STRUCT                0
# GRADE                 0
# CNDTN                 0
# EXTWALL               0
# ROOF                  0
# INTWALL               0
# KITCHENS              0
# FIREPLACES            0
# USECODE               0
# LANDAREA              0
# GIS_LAST_MOD_DTTM     0
# SOURCE                0
# CMPLX_NUM             0
# LIVING_GBA            0
# FULLADDRESS           0
# CITY                  0
# STATE                 0
# ZIPCODE               0
# NATIONALGRID          0
# ...

# %%
df_neigh=df[['ASSESSMENT_NBHD','ASSESSMENT_SUBNBHD']]
df_neigh.drop_duplicates(['ASSESSMENT_NBHD'])
#df.drop_duplicates(['Names'], keep='last')
# Out:
#                      ASSESSMENT_NBHD         ASSESSMENT_SUBNBHD
# 0                         Old City 2           040 D Old City 2
# 92                      Foggy Bottom                        NaN
# 397                    Central-tri 1                        NaN
# 1156                      Old City 1           039 E Old City 1
# 1479            Southwest Waterfront                        NaN
# 3627                    Capitol Hill         009 C Capitol Hill
# 18113                     Georgetown           025 D Georgetown
# 20369                    Glover Park                        NaN
# 20391                       Burleith             008 B Burleith
# 22690                      Palisades            041 B Palisades
# 22725                        Berkley              004 A Berkley
# 22797                        Foxhall                        NaN
# 22862                           Kent                 030 C Kent
# 24296                 Wesley Heights       054 A Wesley Heights
# ...

# %%
df_neigh.drop_duplicates(['ASSESSMENT_NBHD']).count()
# Out:
# ASSESSMENT_NBHD       57
# ASSESSMENT_SUBNBHD    32
# dtype: int64

# %%
#all houses in the "Soutwest Waterfront" - this is not working as hoped
#df.groupby(['ASSESSMENT_NBHD'])
#df

# %%
df_red=df[['BATHRM','BEDRM','ROOMS','HEAT', 'AC','YR_RMDL','LANDAREA','LATITUDE', 'LONGITUDE']]

# %%
df_red_sort=df_red.sort_values('YR_RMDL', ascending=False)
#df.sort_values('hours')
df_red_sort
# Out:
#         BATHRM  BEDRM  ROOMS           HEAT AC  YR_RMDL  LANDAREA   LATITUDE  \
# 70849        3      3      7     Forced Air  Y   2019.0      2434  38.948706
# 68738        3      3      8     Forced Air  Y   2018.0      2794  38.955627
# 55682        3      5     10     Forced Air  Y   2018.0      6843  38.971059
# 75171        3      4      8     Forced Air  Y   2018.0      3328  38.941579
# 105159       2      4      6     Forced Air  Y   2018.0      3076  38.826802
# 102111       2      3      6      Warm Cool  Y   2018.0      2502  38.849353
# 34489        3      3      7  Hot Water Rad  Y   2018.0      2946  38.938464
# 105153       2      2      5     Forced Air  Y   2018.0      3076  38.826816
# 102123       2      3      6     Forced Air  Y   2018.0      1931  38.843670
# 55693        1      3      7  Hot Water Rad  Y   2018.0      4093  38.970793
# 55898        3      4      6     Forced Air  Y   2018.0      1767  38.966993
# ...

# %%
df_red_2014plus=df_red.loc[df_red['YR_RMDL']>=2014]
#df.loc[df['Grades'] <= 100] 
df_red_2014plus.sort_values('YR_RMDL',ascending=False).count()
# Out:
# BATHRM       9839
# BEDRM        9839
# ROOMS        9839
# HEAT         9839
# AC           9839
# YR_RMDL      9839
# LANDAREA     9839
# LATITUDE     9839
# LONGITUDE    9839
# dtype: int64

# %%
df_reduced_land=df_reduced.sort_values('LANDAREA', ascending=False)
df_reduced_land
# Out:
#         BATHRM  BEDRM  ROOMS           HEAT AC  YR_RMDL  LANDAREA   LATITUDE  \
# 34401        8      7     34  Hot Water Rad  Y   2000.0    942632  38.947840
# 40031       14     12     39      Warm Cool  Y   1986.0    691817  38.939016
# 24545       10     12     41      Warm Cool  Y      NaN    498734  38.920770
# 34546        9      7     23     Forced Air  Y      NaN    451804  38.956491
# 34322        6     10     20     Forced Air  Y      NaN    339658  38.940022
# 34320       12     24     48     Forced Air  Y   2009.0    338435  38.960743
# 34321        4      8     16  Hot Water Rad  Y   2001.0    338435  38.960743
# 29163        5      5     18      Warm Cool  Y   2002.0    329174  38.941993
# 38220       10      9     24     Forced Air  Y      NaN    240377  38.934205
# 22103        4     10     18      Warm Cool  Y   2014.0    227446  38.911401
# 24903       10     10     39      Warm Cool  Y      NaN    226479  38.914209
# ...

# %%
#df_reduced['YR_RMDL'] = df_reduced['YR_RMDL'].apply(lambda x: int(x)) #turns float type grades to int type

#df_reduced[df_reduced.loc['YR_RMDL'>=2014]]
#df.loc[df['Grades'] <= 100]

# %%
#find rows equal to 'Southwest WAterfront'
df.loc[df['ASSESSMENT_NBHD'] == 'Southwest Waterfront']
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM        HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 1479          1479       3          1   Warm Cool  Y        1.0      8      4
# 1480          1480       3          1   Warm Cool  Y        1.0      7      3
# 1481          1481       4          1   Warm Cool  Y        1.0      7      4
# 1482          1482       2          1   Warm Cool  Y        1.0      7      3
# 1483          1483       2          1   Warm Cool  Y        1.0      7      4
# 1484          1484       2          1   Warm Cool  Y        1.0      7      3
# 1485          1485       2          1   Warm Cool  Y        1.0      7      3
# 1486          1486       3          1   Warm Cool  Y        1.0     12      4
# 1487          1487       2          1   Warm Cool  Y        1.0      7      2
# 1596          1596       2          1   Warm Cool  Y        1.0      7      2
# 1597          1597       3          1   Warm Cool  Y        1.0      7      3
# ...
